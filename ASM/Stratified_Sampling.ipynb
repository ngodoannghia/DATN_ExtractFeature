# %%
import numpy
import random
import csv
from math import floor

# %%
def stratifed_data(target_file, new_file, spliting_rate=0.2):

#Section 1
    trainlabel = numpy.genfromtxt(target_file, delimiter=",", dtype=str)
    FileName = trainlabel[1:, -2]
    dat = trainlabel[1:, 0:-2]
    dat = dat.astype(numpy.float)
    
    Label = trainlabel[1:, -1]
    Label = Label.astype(numpy.int)
    dat = dat.tolist()
    
    FileName = FileName.tolist()
    Label = Label.tolist()
    
#Section 2
    record = []
    b = []
    count = 0
    temp = []
    starting_index = 0
    
    for i in Label:
        if i not in b:
            if starting_index != 0:
                temp.append(count)
                record.append(temp)
                temp = []
                count = 0
            b.append(i)
            temp.append(i)
            temp.append(starting_index)
        count += 1
        starting_index += 1
    temp.append(count)
    record.append(temp)

#Section 3
    stratified_sample = []
    for i in record:
        count = 0
        temp = []
        while count <= floor(i[2] * spliting_rate):
            a = random.randint(i[1], (i[1] + i[2] - 1))
            if a not in temp:
                count += 1
                temp.append(a)
        stratified_sample.append(temp)

#Section 4
    data_to_write = []
    count = 0
    c = 0
    for i in stratified_sample:
        c += 1
        print('Class ', c, 'Sample = ', len(i))
        count += len(i)
        for j in i:
            a= dat[j]
            a.append(FileName[j].strip('"'))
            a.append(Label[j])
            data_to_write.append(a)
    print('Total samples ', count)
    
    myFile = open(new_file, 'w', newline='')
    with myFile:
        writer = csv.writer(myFile)
        writer.writerows(data_to_write)

# %%
def train_vadilation_split(data_csv, train_csv, validation_csv, traning_data_rate =0.5):
    data_to_write = []
    to_list = []
    
    stratifed_data(data_csv, train_csv, traning_data_rate)
    
    new_train_data = numpy.genfromtxt(train_csv, delimiter=",", dtype = str)
    new_whole_data = numpy.genfromtxt(data_csv, delimiter=",", dtype = str)
    
    for i in new_train_data:
        to_list.append(i[-2]) 
    
    for i in new_whole_data:
        a = i[-2].strip('"')
        if a not in to_list:
            data_to_write.append(i)
    
    myFile = open(validation_csv, 'w', newline='')
    
    with myFile:
        writer = csv.writer(myFile)
        writer.writerows(data_to_write)

# %%
# data = '../Dataset/data/data_apicall/10_reduce_apicall.csv'
# train_full = '../Dataset/data/data_apicall/train_full.csv'
# test = '../Dataset/data/data_apicall/test.csv'
# train = '../Dataset/data/data_apicall/train.csv'
# valid = '../Dataset/data/data_apicall/val.csv'
# data = '../Dataset/data/data_section/12_reduce_section.csv'
# train_full = '../Dataset/data/data_section/train_full.csv'
# test = '../Dataset/data/data_section/test.csv'
# train = '../Dataset/data/data_section/train.csv'
# valid = '../Dataset/data/data_section/val.csv'

data = '../Dataset/data/data_full.csv'
train_full = '../Dataset/data/train_full.csv'
test = '../Dataset/data/test.csv'
train = '../Dataset/data/train.csv'
valid = '../Dataset/data/val.csv'

print('--------------------')
train_vadilation_split(data, train_full, test, 0.75)
print('--------------------')
train_vadilation_split(train_full, train, valid, 0.75)
# Out:
# --------------------
# Class  1 Sample =  1156
# Class  2 Sample =  1859
# Class  3 Sample =  2207
# Class  4 Sample =  357
# Class  5 Sample =  32
# Class  6 Sample =  564
# Class  7 Sample =  299
# Class  8 Sample =  922
# Class  9 Sample =  760
# Total samples  8156
# --------------------
# Class  1 Sample =  867
# Class  2 Sample =  1395
# Class  3 Sample =  1656
# Class  4 Sample =  268
# Class  5 Sample =  25
# Class  6 Sample =  424
# Class  7 Sample =  225
# Class  8 Sample =  692
# Class  9 Sample =  571
# Total samples  6123
